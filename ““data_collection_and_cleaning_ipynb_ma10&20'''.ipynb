# %% [markdown]
# <a href="https://colab.research.google.com/github/vishalkumarlondon/data-viz-coursework-group-2/blob/master/%E2%80%9C%E2%80%9Cdata_collection_and_cleaning_ipynb_ma10%2620'''.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://storage.googleapis.com/public-data-data_viz-2/fashionweeks-2019-instagram-geospatial-clean.csv
# Out:
# --2020-04-20 11:50:28--  https://storage.googleapis.com/public-data-data_viz-2/fashionweeks-2019-instagram-geospatial-clean.csv
# Resolving storage.googleapis.com (storage.googleapis.com)... 108.177.98.128, 2607:f8b0:400e:c04::80
# Connecting to storage.googleapis.com (storage.googleapis.com)|108.177.98.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3254549 (3.1M) [text/csv]
# Saving to: ‘fashionweeks-2019-instagram-geospatial-clean.csv’
#
# fashionweeks-2019-i 100%[===================>]   3.10M  --.-KB/s    in 0.03s
#
# 2020-04-20 11:50:29 (108 MB/s) - ‘fashionweeks-2019-instagram-geospatial-clean.csv’ saved [3254549/3254549]

# %%
import pandas as pd

fashion_weeks_19 = pd.read_csv('fashionweeks-2019-instagram-geospatial-clean.csv')
print(fashion_weeks_19.shape)
# Out:
# (22752, 16)

# %%
#show the fashion week 2019 dataframe
fashion_weeks_19.head()
# Out:
#          date                 time  ...   latitude  longitude
# 0  2019-09-16  2019-09-16 13:39:38  ...  40.702285 -73.995583
# 1  2019-01-06  2019-01-06 18:12:42  ...  40.749904 -73.991040
# 2  2019-09-05  2019-09-05 15:40:45  ...  40.720873 -74.006004
# 3  2019-12-31  2019-12-31 12:56:12  ...  40.720873 -74.006004
# 4  2019-12-31  2019-12-31 03:37:39  ...  40.720839 -74.005973
#
# [5 rows x 16 columns]

# %%
#show the number of posts per city
fashion_weeks_19.filename.value_counts()
# Out:
# nyfw2019    18918
# pfw2019      2052
# lfw2019      1782
# Name: filename, dtype: int64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#airbnb data
# !wget https://storage.googleapis.com/public-data-data_viz-2/london-listings-master-2019.csv
# !wget https://storage.googleapis.com/public-data-data_viz-2/newyork-listings-master-2019.csv
# !wget https://storage.googleapis.com/public-data-data_viz-2/paris-listings-master-2019.csv
# Out:
# --2020-04-20 11:50:33--  https://storage.googleapis.com/public-data-data_viz-2/london-listings-master-2019.csv
# Resolving storage.googleapis.com (storage.googleapis.com)... 108.177.98.128, 2607:f8b0:400e:c09::80
# Connecting to storage.googleapis.com (storage.googleapis.com)|108.177.98.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 114143909 (109M) [text/csv]
# Saving to: ‘london-listings-master-2019.csv’
#
# london-listings-mas 100%[===================>] 108.86M   180MB/s    in 0.6s
#
# 2020-04-20 11:50:34 (180 MB/s) - ‘london-listings-master-2019.csv’ saved [114143909/114143909]
#
# --2020-04-20 11:50:38--  https://storage.googleapis.com/public-data-data_viz-2/newyork-listings-master-2019.csv
# Resolving storage.googleapis.com (storage.googleapis.com)... 108.177.98.128, 2607:f8b0:400e:c05::80
# Connecting to storage.googleapis.com (storage.googleapis.com)|108.177.98.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 79185159 (76M) [text/csv]
# Saving to: ‘newyork-listings-master-2019.csv’
#
# newyork-listings-ma 100%[===================>]  75.52M  31.8MB/s    in 2.4s
#
# 2020-04-20 11:50:41 (31.8 MB/s) - ‘newyork-listings-master-2019.csv’ saved [79185159/79185159]
#
# --2020-04-20 11:50:43--  https://storage.googleapis.com/public-data-data_viz-2/paris-listings-master-2019.csv
# Resolving storage.googleapis.com (storage.googleapis.com)... 108.177.98.128, 2607:f8b0:400e:c09::80
# Connecting to storage.googleapis.com (storage.googleapis.com)|108.177.98.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 102189583 (97M) [text/csv]
# Saving to: ‘paris-listings-master-2019.csv’
#
# paris-listings-mast 100%[===================>]  97.46M  63.7MB/s    in 1.5s
#
# 2020-04-20 11:50:45 (63.7 MB/s) - ‘paris-listings-master-2019.csv’ saved [102189583/102189583]

# %%
london_airbnb = pd.read_csv('london-listings-master-2019.csv')
newyork_airbnb = pd.read_csv('newyork-listings-master-2019.csv')
paris_airbnb = pd.read_csv('paris-listings-master-2019.csv')
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
print(london_airbnb.shape, newyork_airbnb.shape, paris_airbnb.shape)
# Out:
# (840212, 16) (592519, 16) (744575, 16)

# %%
london_airbnb.isna().sum()
# Out:
# Unnamed: 0                0
# id                        0
# host_id                   0
# last_scraped              0
# zipcode               19541
# latitude                 10
# longitude                10
# neighbourhood            16
# property_type            10
# room_type                10
# price                    10
# number_of_reviews        10
# last_review          208100
# year_scraped              0
# month_scraped             0
# day_scraped               0
# dtype: int64

# %%
london_airbnb.dropna()
# Out:
#         Unnamed: 0        id  ...  month_scraped day_scraped
# 0                0  29588041  ...              7          12
# 1                1   2456256  ...              7          12
# 2                2  28972251  ...              7          12
# 3                3  14074467  ...              7          12
# 4                4  28973074  ...              7          12
# ...            ...       ...  ...            ...         ...
# 840179     1872147  39377815  ...             11           6
# 840180     1872148  39284619  ...             11           6
# 840182     1872150  39740287  ...             11           6
# 840192     1872160  22701498  ...             11           6
# 840196     1872164  38398365  ...             11           6
#
# [617431 rows x 16 columns]

# %%
london_airbnb.describe()
# Out:
#          Unnamed: 0            id  ...  month_scraped    day_scraped
# count  8.402120e+05  8.402120e+05  ...  840212.000000  840212.000000
# mean   9.362641e+05  2.158722e+07  ...       7.574217       9.865426
# std    7.226262e+05  1.056149e+07  ...       2.848704       3.277162
# min    0.000000e+00  1.155100e+04  ...       3.000000       5.000000
# 25%    2.100528e+05  1.367955e+07  ...       5.000000       7.000000
# 50%    1.364838e+06  2.209394e+07  ...       8.000000      10.000000
# 75%    1.662126e+06  3.038785e+07  ...      10.000000      11.000000
# max    1.872179e+06  4.067901e+07  ...      12.000000      30.000000
#
# [8 rows x 9 columns]

# %%
london_airbnb['price_float'] = london_airbnb['price'].str.replace(',', '').astype(float)

# %%
london_airbnb.describe()
# Out:
#          Unnamed: 0            id  ...    day_scraped    price_float
# count  8.402120e+05  8.402120e+05  ...  840212.000000  840202.000000
# mean   9.362641e+05  2.158722e+07  ...       9.865426     121.185726
# std    7.226262e+05  1.056149e+07  ...       3.277162     252.993055
# min    0.000000e+00  1.155100e+04  ...       5.000000       0.000000
# 25%    2.100528e+05  1.367955e+07  ...       7.000000      45.000000
# 50%    1.364838e+06  2.209394e+07  ...      10.000000      80.000000
# 75%    1.662126e+06  3.038785e+07  ...      11.000000     137.000000
# max    1.872179e+06  4.067901e+07  ...      30.000000   20000.000000
#
# [8 rows x 10 columns]

# %%
mean = london_airbnb['price_float'].mean()
mean
# Out:
# 121.18572557551636

# %%
std = london_airbnb['price_float'].std()
std
# Out:
# 252.99305545327857

# %%
london_airbnb.price_float
# Out:
# 0          30.0
# 1          23.0
# 2          70.0
# 3          38.0
# 4          50.0
#           ...
# 840207     70.0
# 840208     69.0
# 840209     90.0
# 840210     30.0
# 840211    187.0
# Name: price_float, Length: 840212, dtype: float64

# %%
london_airbnb_1 = london_airbnb[london_airbnb['price_float']<=880]
london_airbnb_1
# Out:
#         Unnamed: 0        id  ...  day_scraped price_float
# 0                0  29588041  ...           12        30.0
# 1                1   2456256  ...           12        23.0
# 2                2  28972251  ...           12        70.0
# 3                3  14074467  ...           12        38.0
# 4                4  28973074  ...           12        50.0
# ...            ...       ...  ...          ...         ...
# 840207     1872175  39868875  ...            6        70.0
# 840208     1872176  39869123  ...            6        69.0
# 840209     1872177  39869214  ...            6        90.0
# 840210     1872178  39869249  ...            6        30.0
# 840211     1872179  39869282  ...            6       187.0
#
# [834019 rows x 17 columns]

# %%
london_airbnb_1.dropna()
# Out:
#         Unnamed: 0        id  ...  day_scraped price_float
# 0                0  29588041  ...           12        30.0
# 1                1   2456256  ...           12        23.0
# 2                2  28972251  ...           12        70.0
# 3                3  14074467  ...           12        38.0
# 4                4  28973074  ...           12        50.0
# ...            ...       ...  ...          ...         ...
# 840179     1872147  39377815  ...            6        50.0
# 840180     1872148  39284619  ...            6       260.0
# 840182     1872150  39740287  ...            6       150.0
# 840192     1872160  22701498  ...            6       115.0
# 840196     1872164  38398365  ...            6       117.0
#
# [615079 rows x 17 columns]

# %%
london_airbnb_1['last_review'] = pd.to_datetime(london_airbnb_1['last_review'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
london_airbnb_1.sort_values('last_review', inplace=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
london_airbnb_1.head()
# Out:
#         Unnamed: 0     id  host_id  ... month_scraped day_scraped  price_float
# 372118      372118  41870   182993  ...             3           8         35.0
# 231730      231730  41870   182993  ...             5           6         35.0
# 294475      294475  41870   182993  ...             4          11         35.0
# 405469     1350202  41870   182993  ...            12          11         35.0
# 94393        94393  41870   182993  ...             6           7         35.0
#
# [5 rows x 17 columns]

# %%
london_airbnb_1.shape
# Out:
# (834019, 17)

# %%
london_airbnb_1['date'] = london_airbnb_1['last_review']
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
london_airbnb_1.set_index("date", inplace=True)

# %%
london_airbnb_2019 = london_airbnb_1[london_airbnb_1['last_review']>=pd.datetime(2019,1,1)]
london_airbnb_2019
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime instead.
#   """Entry point for launching an IPython kernel.
#             Unnamed: 0        id  ...  day_scraped price_float
# date                              ...
# 2019-01-01      263402  30796568  ...           11        20.0
# 2019-01-01     1733430  19017872  ...            9       149.0
# 2019-01-01      245948  27945618  ...            5        30.0
# 2019-01-01     1629301  13851334  ...           15        70.0
# 2019-01-01      285577  25828718  ...           11       150.0
# ...                ...       ...  ...          ...         ...
# 2019-12-11     1420054  36381892  ...           11        69.0
# 2019-12-11     1401873  28450140  ...           11        85.0
# 2019-12-11     1430942  39527801  ...           11       100.0
# 2019-12-11     1359021   6872783  ...           11       100.0
# 2019-12-11     1430377  39385120  ...           11        80.0
#
# [410945 rows x 17 columns]

# %%
london_airbnb_2019.dropna()
# Out:
#             Unnamed: 0        id  ...  day_scraped price_float
# date                              ...
# 2019-01-01      263402  30796568  ...           11        20.0
# 2019-01-01     1733430  19017872  ...            9       149.0
# 2019-01-01      245948  27945618  ...            5        30.0
# 2019-01-01     1629301  13851334  ...           15        70.0
# 2019-01-01      285577  25828718  ...           11       150.0
# ...                ...       ...  ...          ...         ...
# 2019-12-11     1420054  36381892  ...           11        69.0
# 2019-12-11     1401873  28450140  ...           11        85.0
# 2019-12-11     1430942  39527801  ...           11       100.0
# 2019-12-11     1359021   6872783  ...           11       100.0
# 2019-12-11     1430377  39385120  ...           11        80.0
#
# [401803 rows x 17 columns]

# %%
plt.figure(figsize=(16,10), dpi= 80)
plt.plot('last_review', 'price_float', data=london_airbnb_2019, color='tab:red')

# %%
london_airbnb_2019_day= london_airbnb_2019.resample('D').mean()
london_airbnb_2019_day = london_airbnb_2019_day.round(3)
london_airbnb_2019_day
# Out:
#              Unnamed: 0            id  ...  day_scraped  price_float
# date                                   ...
# 2019-01-01   606189.818  2.108613e+07  ...        9.129      113.867
# 2019-01-02   606677.986  2.021317e+07  ...        9.077      121.921
# 2019-01-03   625997.801  1.982571e+07  ...        9.133      124.692
# 2019-01-04   612052.311  1.866591e+07  ...        9.130      133.680
# 2019-01-05   586243.958  1.889251e+07  ...        9.080      133.648
# ...                 ...           ...  ...          ...          ...
# 2019-12-07  1401361.366  2.732445e+07  ...       10.396       89.540
# 2019-12-08  1401520.167  2.737199e+07  ...       10.429       93.315
# 2019-12-09  1401380.710  2.727290e+07  ...       10.501       91.292
# 2019-12-10  1402149.970  2.735700e+07  ...       10.628       82.020
# 2019-12-11  1405955.000  2.857790e+07  ...       11.000       94.875
#
# [345 rows x 10 columns]

# %%
london_airbnb_2019_day.dropna()
# Out:
#              Unnamed: 0            id  ...  day_scraped  price_float
# date                                   ...
# 2019-01-01   606189.818  2.108613e+07  ...        9.129      113.867
# 2019-01-02   606677.986  2.021317e+07  ...        9.077      121.921
# 2019-01-03   625997.801  1.982571e+07  ...        9.133      124.692
# 2019-01-04   612052.311  1.866591e+07  ...        9.130      133.680
# 2019-01-05   586243.958  1.889251e+07  ...        9.080      133.648
# ...                 ...           ...  ...          ...          ...
# 2019-12-07  1401361.366  2.732445e+07  ...       10.396       89.540
# 2019-12-08  1401520.167  2.737199e+07  ...       10.429       93.315
# 2019-12-09  1401380.710  2.727290e+07  ...       10.501       91.292
# 2019-12-10  1402149.970  2.735700e+07  ...       10.628       82.020
# 2019-12-11  1405955.000  2.857790e+07  ...       11.000       94.875
#
# [345 rows x 10 columns]

# %%
london_airbnb_2019_day['ma10'] = london_airbnb_2019_day['price_float'].rolling(10).mean().shift(-9)
london_airbnb_2019_day['ma20'] = london_airbnb_2019_day['price_float'].rolling(20).mean().shift(-19)

# %%
london_airbnb_2019_day.plot( y=["ma10",'ma20'], style='-',figsize=(16,10))
plt.show()

# %%
newyork_airbnb['price_float'] = newyork_airbnb['price'].str.replace(',', '').astype(float)

# %%
mean = newyork_airbnb['price_float'].mean()
std = newyork_airbnb['price_float'].std()
mean
# Out:
# 152.92387782105897

# %%
s = mean+3*std
s
# Out:
# 919.8566989844694

# %%
newyork_airbnb_1 = newyork_airbnb[newyork_airbnb['price_float']<=s]
newyork_airbnb_1
# Out:
#         Unnamed: 0          id  ...  day_scraped price_float
# 0                0  32239035.0  ...            7       170.0
# 1                1  14389040.0  ...            7       200.0
# 2                2  14378713.0  ...            7        38.0
# 3                3  14381523.0  ...            7       229.0
# 4                4  14382631.0  ...            7       147.0
# ...            ...         ...  ...          ...         ...
# 592514     2438321  35291681.0  ...            3        60.0
# 592515     2438322  35292625.0  ...            3        86.0
# 592516     2438323  35297530.0  ...            3       160.0
# 592517     2438324  35301609.0  ...            3        89.0
# 592518     2438325  35303893.0  ...            3       249.0
#
# [588157 rows x 17 columns]

# %%
newyork_airbnb_1.dropna()
# Out:
#         Unnamed: 0          id  ...  day_scraped price_float
# 1                1  14389040.0  ...            7       200.0
# 2                2  14378713.0  ...            7        38.0
# 3                3  14381523.0  ...            7       229.0
# 4                4  14382631.0  ...            7       147.0
# 5                5  14383283.0  ...            7        35.0
# ...            ...         ...  ...          ...         ...
# 592332     2438139  35224560.0  ...            3        55.0
# 592381     2438188  35235379.0  ...            3        36.0
# 592388     2438195  35238264.0  ...            3       100.0
# 592424     2438231  35257450.0  ...            3       350.0
# 592486     2438293  35279737.0  ...            3        60.0
#
# [459241 rows x 17 columns]

# %%
newyork_airbnb_1['last_review'] = pd.to_datetime(newyork_airbnb_1['last_review'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
newyork_airbnb_1.sort_values('last_review', inplace=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
plt.figure(figsize=(16,10), dpi= 80)
plt.plot('last_review', 'price_float', data=newyork_airbnb_1, color='tab:red')

# %%
newyork_airbnb_1['date'] = newyork_airbnb_1['last_review']
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
newyork_airbnb_1.set_index("date", inplace=True)

# %%
newyork_airbnb_2019 = newyork_airbnb_1[newyork_airbnb_1['last_review']>=pd.datetime(2019,1,1)]
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime instead.
#   """Entry point for launching an IPython kernel.

# %%
plt.figure(figsize=(16,10), dpi= 80)
plt.plot('last_review', 'price_float', data=newyork_airbnb_2019, color='tab:red')

# %%
newyork_airbnb_2019_day= newyork_airbnb_2019.resample('D').mean()
newyork_airbnb_2019_day = newyork_airbnb_2019_day.round(3)

# %%
newyork_airbnb_2019_day['ma10'] = newyork_airbnb_2019_day['price_float'].rolling(10).mean().shift(-9)
newyork_airbnb_2019_day['ma20'] = newyork_airbnb_2019_day['price_float'].rolling(20).mean().shift(-19)

# %%
newyork_airbnb_2019_day.plot( y=["ma10",'ma20'], style='-',figsize=(16,10))
plt.show()

# %%
paris_airbnb['price_float'] = paris_airbnb['price'].str.replace(',', '').astype(float)

# %%
mean = paris_airbnb['price_float'].mean()
std = paris_airbnb['price_float'].std()
mean
# Out:
# 117.30541315515562

# %%
s = mean+3*std
s
# Out:
# 714.7627072818117

# %%
paris_airbnb_1 = paris_airbnb[paris_airbnb['price_float']<=s]
paris_airbnb_1
# Out:
#         Unnamed: 0        id  ...  day_scraped price_float
# 0                0      3109  ...           18        60.0
# 1                1      5396  ...           18       115.0
# 2                2      7397  ...           17       119.0
# 3                3      7964  ...           18       130.0
# 4                4      8522  ...           18        90.0
# ...            ...       ...  ...          ...         ...
# 744570      877815  40703044  ...           12        90.0
# 744571      877816  40703081  ...           12       200.0
# 744572      877817  40703619  ...           12       320.0
# 744573      877818  40704453  ...           12       105.0
# 744574      877819  40712221  ...           11        90.0
#
# [736371 rows x 17 columns]

# %%
paris_airbnb_1.dropna()
# Out:
#         Unnamed: 0        id  ...  day_scraped price_float
# 0                0      3109  ...           18        60.0
# 1                1      5396  ...           18       115.0
# 2                2      7397  ...           17       119.0
# 3                3      7964  ...           18       130.0
# 4                4      8522  ...           18        90.0
# ...            ...       ...  ...          ...         ...
# 744486      877731  40686846  ...           12       119.0
# 744518      877763  40690008  ...           12        40.0
# 744521      877766  40690822  ...           12        85.0
# 744556      877801  40699261  ...           12        80.0
# 744559      877804  40700433  ...           12        44.0
#
# [572586 rows x 17 columns]

# %%
paris_airbnb_1['last_review'] = pd.to_datetime(paris_airbnb_1['last_review'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
paris_airbnb_1.sort_values('last_review', inplace=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
plt.figure(figsize=(16,10), dpi= 80)
plt.plot('last_review', 'price_float', data=paris_airbnb_1, color='tab:red')
plt.rcParams['agg.path.chunksize'] = 10000

# %%
london_airbnb_2019_day['ma10'] = london_airbnb_2019_day['price_float'].rolling(10).mean().shift(-9)
london_airbnb_2019_day['ma20'] = london_airbnb_2019_day['price_float'].rolling(20).mean().shift(-19)
london_airbnb_2019_day.plot( y=["ma10",'ma20'], style='-',figsize=(16,10))
plt.show()

# %%
paris_airbnb_1['date'] = paris_airbnb_1['last_review']
paris_airbnb_1.set_index("date", inplace=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
paris_airbnb_2019 = paris_airbnb_1[paris_airbnb_1['last_review']>=pd.datetime(2019,1,1)]
paris_airbnb_2019.dropna()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime instead.
#   """Entry point for launching an IPython kernel.
#             Unnamed: 0        id  ...  day_scraped price_float
# date                              ...
# 2019-01-01      588221  10334886  ...           14       150.0
# 2019-01-01      109707  27323550  ...           12        60.0
# 2019-01-01      611190  23087864  ...           14        30.0
# 2019-01-01      624822  30420392  ...           14       370.0
# 2019-01-01      481707  21571568  ...            9       170.0
# ...                ...       ...  ...          ...         ...
# 2019-12-18      857454  30649781  ...           19        60.0
# 2019-12-18      867970  36536579  ...           19        78.0
# 2019-12-18      873052  38951158  ...           19        91.0
# 2019-12-18      873167  39011489  ...           19        61.0
# 2019-12-19      870060  37309832  ...           20        38.0
#
# [328590 rows x 17 columns]

# %%
plt.figure(figsize=(16,10), dpi= 80)
plt.plot('last_review', 'price_float', data=paris_airbnb_2019, color='tab:red')

# %%
paris_airbnb_2019_day= paris_airbnb_2019.resample('D').mean()
paris_airbnb_2019_day = paris_airbnb_2019_day.round(3)
paris_airbnb_2019_day
paris_airbnb_2019_day.dropna()
# Out:
#             Unnamed: 0            id  ...  day_scraped  price_float
# date                                  ...
# 2019-01-01  496196.797  1.874535e+07  ...       10.234      114.100
# 2019-01-02  499546.000  1.771014e+07  ...       10.157      120.542
# 2019-01-03  497353.254  1.759034e+07  ...       10.130      116.784
# 2019-01-04  510443.847  1.693995e+07  ...       10.166      129.020
# 2019-01-05  507399.605  1.677888e+07  ...       10.139      132.433
# ...                ...           ...  ...          ...          ...
# 2019-12-14  864074.333  3.418218e+07  ...       19.083       75.833
# 2019-12-15  874886.000  3.970990e+07  ...       19.000      117.000
# 2019-12-16  872040.000  3.833317e+07  ...       19.500      184.500
# 2019-12-18  867910.750  3.628725e+07  ...       19.000       72.500
# 2019-12-19  870060.000  3.730983e+07  ...       20.000       38.000
#
# [352 rows x 10 columns]

# %%
paris_airbnb_2019_day['ma10'] = paris_airbnb_2019_day['price_float'].rolling(10).mean().shift(-9)
paris_airbnb_2019_day['ma20'] = paris_airbnb_2019_day['price_float'].rolling(20).mean().shift(-19)
paris_airbnb_2019_day.plot( y=["ma10",'ma20'], style='-',figsize=(16,10))
plt.show()
